# %%
from pandas import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = read_csv('company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1700        21300        211000
# 1          1300        18430        183300
# 2          1340        22470        224700
# 3          4000        25140        222700
# 4          1740        20960        209600
# 5          1590        20175        201400
# 6          3000        22640        295500
# 7          1500        25280        361400
# 8          1780        23400        234000
# 9          3800        28580        266700
# 10         2100        29540        412800
# 11         1900        30160        300200

# %% [markdown]
# # Exercício 1

# %%
x=df.month_number
y=df.total_profit
plt.plot(x,y)
plt.xticks(x, x, rotation='horizontal')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title("Company profit per month")
plt.show()

# %% [markdown]
# # Exercício 2

# %%
plt.figure(figsize=(9,5))

x=df.month_number
y=df.total_profit

plt.plot(df.month_number, df.total_profit, 'r--.', markersize=6, marker="o", markerfacecolor='white', linewidth=3, label="Profit/last year")

plt.title("Company profit per month")
plt.xlabel('Month Number')
plt.ylabel('Profit in Dollar')

plt.legend(["Profit data of last year"], loc='lower right')
plt.show()

# %% [markdown]
# # Exercício 3

# %%
plt.figure(figsize=(9,5))


x=df.month_number
y=df.total_profit

plt.title("Sales Data")
plt.xlabel('Month Number')
plt.ylabel('Sales Units')


p1 = plt.plot(df.facecream, '.-', markersize=12, linewidth=3, label="Face Cream")
p2 = plt.plot(df.facewash, '.-', markersize=12, linewidth=3, label="Face Wash")
p3 = plt.plot(df.toothpaste, '.-', markersize=12, linewidth=3, label="Toothpaste")
p4 = plt.plot(df.bathingsoap, '.-', markersize=12, linewidth=3, label="Bathing Soap")
p5 = plt.plot(df.shampoo, '.-', markersize=12, linewidth=3, label="Shampoo")
p6 = plt.plot(df.moisturizer, '.-', markersize=12, linewidth=3, label="Moisturizer")

plt.legend()
plt.show()

# %% [markdown]
# # Exercício 4

# %%
sum_column = df.sum(axis=0)
TotalS = sum_column


TotalSalesFC = (TotalS.facecream/TotalS.total_units)
TotalSalesFW = (TotalS.facewash/TotalS.total_units)
TotalSalesTP = (TotalS.toothpaste/TotalS.total_units)
TotalSalesBS = (TotalS.bathingsoap/TotalS.total_units)
TotalSalesSH = (TotalS.shampoo/TotalS.total_units)
TotalSalesMO = (TotalS.moisturizer/TotalS.total_units)

data = [TotalSalesFC,TotalSalesFW,TotalSalesTP,TotalSalesBS,TotalSalesSH,TotalSalesMO]
label = ["Face Cream","Face Wash","Tooth Paste","Bathing Soap","Shampoo","Moisturizer"]

plt.axis("equal")
plt.pie(data,labels = label,radius=1.5,autopct = "%0.0f%%", startangle=300)


plt.show()
